# %% [markdown]
# <a href="https://colab.research.google.com/github/Lee-Geunhee/Lee-Geunhee/blob/main/ddd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/train_data.csv')

# %%
df
# Out:
#         id  age  gender  respiratory_condition  fever_or_muscle_pain  covid19
# 0        1   24  female                      0                     1        0
# 1        2   51    male                      0                     0        0
# 2        3   22    male                      0                     0        0
# 3        4   29  female                      1                     0        0
# 4        5   23    male                      0                     0        0
# ...    ...  ...     ...                    ...                   ...      ...
# 3800  3801   53    male                      0                     0        0
# 3801  3802   25    male                      0                     0        0
# 3802  3803   26  female                      0                     0        0
# 3803  3804   27  female                      0                     0        0
# 3804  3805   49  female                      1                     1        0
#
# [3805 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3805 entries, 0 to 3804
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3805 non-null   int64
#  1   age                    3805 non-null   int64
#  2   gender                 3805 non-null   object
#  3   respiratory_condition  3805 non-null   int64
#  4   fever_or_muscle_pain   3805 non-null   int64
#  5   covid19                3805 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 178.5+ KB

# %%
df.describe()
# Out:
#                 id          age  respiratory_condition  fever_or_muscle_pain  \
# count  3805.000000  3805.000000            3805.000000           3805.000000
# mean   1903.000000    36.768463               0.144809              0.084625
# std    1098.553215    14.708248               0.351955              0.278360
# min       1.000000     1.000000               0.000000              0.000000
# 25%     952.000000    25.000000               0.000000              0.000000
# 50%    1903.000000    35.000000               0.000000              0.000000
# 75%    2854.000000    46.000000               0.000000              0.000000
# max    3805.000000    90.000000               1.000000              1.000000
#
#            covid19
# count  3805.000000
# mean      0.080420
# std       0.271979
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
df['age'].min()
# Out:
# 1

# %%
df['fever_or_muscle_pain'].value_counts()
# Out:
# 0    3483
# 1     322
# Name: fever_or_muscle_pain, dtype: int64

# %%
df
# Out:
#         id  age  gender  respiratory_condition  fever_or_muscle_pain  covid19
# 0        1   24  female                      0                     1        0
# 1        2   51    male                      0                     0        0
# 2        3   22    male                      0                     0        0
# 3        4   29  female                      1                     0        0
# 4        5   23    male                      0                     0        0
# ...    ...  ...     ...                    ...                   ...      ...
# 3800  3801   53    male                      0                     0        0
# 3801  3802   25    male                      0                     0        0
# 3802  3803   26  female                      0                     0        0
# 3803  3804   27  female                      0                     0        0
# 3804  3805   49  female                      1                     1        0
#
# [3805 rows x 6 columns]

# %%
df.loc[ df['age'] <= 10, 'age_clean'] = 0
df.loc[(df['age'] > 10) & (df['age'] <= 20), 'age_clean'] = 1
df.loc[(df['age'] > 20) & (df['age'] <= 30), 'age_clean'] = 2
df.loc[(df['age'] > 30) & (df['age'] <= 40), 'age_clean'] = 3
df.loc[(df['age'] > 40) & (df['age'] <= 50), 'age_clean'] = 4
df.loc[(df['age'] > 50) & (df['age'] <= 60), 'age_clean'] = 5
df.loc[(df['age'] > 60) & (df['age'] <= 70), 'age_clean'] = 6
df.loc[(df['age'] > 70) & (df['age'] <= 80), 'age_clean'] = 7
df.loc[(df['age'] > 80) & (df['age'] <= 90), 'age_clean'] = 8
df.loc[(df['age'] > 90) & (df['age'] <= 100), 'age_clean'] =9

# %%
df
# Out:
#         id  age  gender  respiratory_condition  fever_or_muscle_pain  covid19  \
# 0        1   24  female                      0                     1        0
# 1        2   51    male                      0                     0        0
# 2        3   22    male                      0                     0        0
# 3        4   29  female                      1                     0        0
# 4        5   23    male                      0                     0        0
# ...    ...  ...     ...                    ...                   ...      ...
# 3800  3801   53    male                      0                     0        0
# 3801  3802   25    male                      0                     0        0
# 3802  3803   26  female                      0                     0        0
# 3803  3804   27  female                      0                     0        0
# 3804  3805   49  female                      1                     1        0
#
#       age_clean
# ...

# %%
df['age_clean'].value_counts()
# Out:
# 2.0    1045
# 3.0     921
# 4.0     730
# 1.0     412
# 5.0     397
# 6.0     172
# 7.0      78
# 0.0      35
# 8.0      15
# Name: age_clean, dtype: int64

# %%
len(df.loc[(df['age_clean']==2.0 & df['covid19']==1)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
# ...

# %%
len(df.loc[df['covid19'] == 0])
# Out:
# 3499

# %%
print(len(df.loc[(df['age_clean'] ==8) & (df['covid19'] == 1)]))
print(len(df.loc[(df['fever_or_muscle_pain'] ==0) & (df['covid19'] == 1)]))
# Out:
# 2
# 223

# %%
pip install praat-parselmouth
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 10.7 MB 3.8 MB/s
# ...
